# %% [markdown]
# <a href="https://colab.research.google.com/github/Dakotamjohnson/DMJohnson/blob/main/Week5DAkotaJohnson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install altair

# %%
import pandas as pd
import altair as alt

# %%
from vega_datasets import data as vega_data
moviesDF = pd.read_json(vega_data.movies.url)
print("moviesDF is of the type: ", type(movies_df))
print("moviesDF: ", movies_df.shape)
# Out:
# moviesDF is of the type:  <class 'pandas.core.frame.DataFrame'>
# moviesDF:  (3201, 17)

# %%
def extract_year(value):
    return pd.to_datetime(value, format='%b %d %Y').year

moviesDF["Year"] = moviesDF["Release_Date"].apply(extract_year)

# %%
movies1997 = moviesDF[moviesDF["Year"] == 1997]
movies1997.shape
# Out:
# (97, 17)

# %%
alt.Chart(movies1997).mark_point().encode(
    alt.X ("Production_Budget"),
    alt.Y ("Worldwide_Gross")
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(movies1997).mark_point().encode(
    alt.X ("Production_Budget"),
    alt.Y ("Worldwide_Gross"),
    alt.Color("Major_Genre"),
    alt.OpacityValue(0.8)
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(movies1997).mark_bar().encode(
    alt.X ("Major_Genre"),
    alt.Y ("Worldwide_Gross"),
    alt.Color("Major_Genre"),
    alt.OpacityValue(0.3)
)
# Out:
# alt.Chart(...)
